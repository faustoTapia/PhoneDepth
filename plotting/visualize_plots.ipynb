# %%
import sys
sys.path.append('../')
from plotting.plotting_utils import data_frame_to_metric_dic
from plotting.plotting_utils import model_training_epochs, plot_metrics_from_datadicts, load_models_data_dics, plot_training_from_datadics
import pandas as pd
from matplotlib import pyplot as plt

# %%
training_data_dir = '/home/tfausto/code/efficient_depth_thesis/depth_estimation_codes/plotting/data'
model_name = 'effB3_pynet_pxlShuffle_depsep_md_288x288_32fil_5dep'
model_data_frame = "data/" + model_name + ".csv"
training_data_frame = pd.read_csv(model_data_frame)
metrics_dic = data_frame_to_metric_dic(training_data_frame, layer_epochs=model_training_epochs[model_name])
training_curves_data = load_models_data_dics(data_frames_dir=training_data_dir)

# %%
# # Plot 1
# models = ["unet_quad_md_224x224",
#           "unet_quad_md_288x288",
#           "park_mai_md_224x224"]
# labels = ["Unet-quad 224x224",
#           "Unet-quad 288x288",
#           "Park 224x224"]
# font_size = 20
# loss_range=(0.02, 0.1)
# metric_range=(0.04, 0.20)
# file_name = "baselines_training.png"


# # Plot 2
# models = ["park_mai_md_224x224",
#           "mobilepy_small_net_md_224x224_32fil_5dep",
#           "mobilepy_net_md_128x128_16fil_5dep"]
# labels = ["Park 224x224",
#           "Mobile_pynetsmall_224x224",
#           "Mobile_pynet_128x128_half"]
# font_size = 20
# loss_range=(0.00, 0.1)
# metric_range=(0.00, 0.20)
# file_name = "mobilenet_scalieup.png"

# # Plot 3
# models = ["park_mai_md_224x224",
#           "effnetB0parkmai_md_224x224",
#           "effnetB1parkmai_md_256x256"]
# labels = ["Park 224x224",
#           "EffnetB0_park_224x224",
#           "EffnetB1_park_256x256"]
# font_size = 20
# loss_range=(0.00, 0.1)
# metric_range=(0.00, 0.20)
# file_name = "mobilenet_scalieup.png"

# # Plot 4
# models = ["effB1_pynetsmall_depsep_md_256x256_32fil_5dep",
#           "mobilepy_small_net_md_224x224_32fil_5dep",
#           "effB1_pynetsmall_dualatt_depsep_md_256x256_32fil_5dep",
#           "effB1_pynetsmall_globNonLoc_depsep_md_256x256_32fil_5dep",
#           "mobilepy_net_atrous_depsep_gate_md_224x224_16fil_5dep"]
# labels = ["EffnetB1_pynetsmall_256x256",
#           "Mobile_pynetsmall_224x224",
#           "EffnetB1_dualatt_pynetsmall_256x256",
#           "EffnetB1_globNonLoc_pynetsmall_256x256",
#           "Mobile_gatedAtt_pynet224x224"]
# font_size = 20
# loss_range=(0.00, 0.1)
# metric_range=(0.00, 0.20)
# file_name = "skip_blocks.png"

# # Plot 5
# models = ["effB1_pynetsmall_dualatt_depsep_md_256x256_32fil_5dep",
#           "effB3_pynet_transposeConv_depsep_md_288x288_32fil_5dep",
#           "effB3_pynet_pxlShuffle_depsep_md_288x288_32fil_5dep"]
# labels = ["EffnetB1_dualatt_pynetsmall_256x256",
#           "EffnetB3_pynet_transposeConv_288x288",
#           "EffnetB3_pynet_pxlShuffle_288x288"]
# font_size = 20
# loss_range=(0.00, 0.1)
# metric_range=(0.00, 0.20)
# file_name = "upscale_out.png"

# # Plot 6
# models = ["effB4_pynet_pxlShuffle_depsep_md_256x256_32fil_5dep",
#           "effB4_pynet_pxlShuffle_depsep_md_288x288_32fil_5dep",
#           "effB4_pynet_pxlShuffle_depsep_md_320x320_32fil_5dep"]

# labels = ["EffnetB4_pynet_pxlShuffle_256x256",
#           "EffnetB4_pynet_pxlShuffle_288x288",
#           "EffnetB4_pynet_pxlShuffle_320x320"]

# font_size = 20
# loss_range=(0.00, 0.1)
# metric_range=(0.00, 0.20)
# file_name = "io_resolution.png"

# # Plot 7
# models = ["effnetB4parkmai_md_384x384",
#           "effnetB4_dualatt_parkmai_md_384x384",
#           "effnetB4_dualatt_parkmai_imdb_md_384x384",
#           "effnetB4_dualatt_parkmai_group_convs_g4_n3_md_384x384",
#           "effnetB4_dualatt_parkmai_rrdb_depthsep_md_384x384"]

# labels = ["EffnetB4_park_384x384",
#           "EffnetB4_dualatt_park_384x384",
#           "EffnetB4_dualatt_imdb_park_384x384",
#           "EffnetB4_dualatt_group_park_384x384",
#           "EffnetB4_dualatt_rrdb_park384x384"]

# font_size = 20
# loss_range=(0.03, 0.06)
# metric_range=(0.025, 0.10)
# file_name = "building_blocks_plots.png"


# Plot 8
models = ["effnetB4_I2DhuaDepth_dualatt_parkmai_imdb_mb_384x384",
          "effnetB4_I2PhuaDepth_dualatt_parkmai_imdb_mb_384x384",
          "effnetB4_I2DPhuaDepth_dualatt_parkmai_imdb_mb_384x384",
          "effnetB4_ID2PhuaDepth_dualatt_parkmai_imdb_mb_384x384",
          "effnetB4_ID2DPhuaDepth_dualatt_parkmai_imdb_mb_384x384"]

labels = ["I2D",
          "I2P",
          "I2DP",
          "ID2P",
          "ID2DP"]

font_size = 20
loss_range=(0.00, 0.2)
metric_range=(0.03, 0.5)
epochs_range = (0, 100)
file_name = "phoneDepth_plots.png"


data_dics = [training_curves_data[model] for model in models]

fig = plot_training_from_datadics(data_dics, labels=labels, loss_range=loss_range, font_size=font_size, metric_range=metric_range, epochs_range=epochs_range, figsize=(12, 12))
fig.savefig("../plotting_results/" + file_name)
